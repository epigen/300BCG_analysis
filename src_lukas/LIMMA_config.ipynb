# %%
import yaml
import os
from misc import *
from bcg_colors import *
from pandas.api.types import is_bool_dtype
_ = setup_plotting(style='ticks', context='talk')

# %%
DATA_DIR = os.path.join(DATA, 'DE')
RESULTS_DIR = 'results_bootstrap'
DATA_DIR, RESULTS_DIR
# Out:
# ('../data/DE', 'results_bootstrap')

# %%
LOLA_DB_DIR = 'resources/LOLA'
LOLA_DB = ['LOLAbcg/hg38']
LOLA_COLLECTIONS = [HOCOMOCO, EPI_ROADMAP, 'leukotypes']

# %%
FULL_BCG_PTHW_SET = [BCG_PATHWAYS] + ['{}_min15_max500'.format(lib) for lib in [KEGG, GO_BIO_PROCESS]]
WHICH_REGIONS = [GENE_AND_DISTAL_10kb, TSS_PROXIMAL]
RANK_METRIC = 'p.value'
TOP_N = 1000

# %% [markdown]
# #### Variance partitioning

# %%
celltype = 'PBMC'
annot_fn = SAMPLE_ANNOT_FN.format(which='.corrected')
print(annot_fn)
_annot_df = get_sample_annot(annot_fn)

for batch_corrected, normal_data, model, columns, random_effects, counts in [
    (True, False, 'varPartTop.batch_TSS_enr_blood_corrected.donor',
     ['SAMPLE.DONOR'], '(1|SAMPLE.DONOR)',
     os.path.join(DATA_DIR, 'blood_TSS_enr_corrected_combat_normalized_log2_CPM_PBMC.csv.gz')),
]:
    config = {}
    config['results_dir'] = RESULTS_DIR
    config['debug'] = False
    config['batch_corrected'] = batch_corrected
    config['dream'] = False
    config['var_part'] = True

    config['celltype'] = celltype
    config['model'] = model
    config['annot_fn'] = annot_fn
    config['peak_fn'] = os.path.join(DATA_DIR, 'peaks_filtered_PBMC.csv.gz')
    config['counts_fn'] = counts if counts else os.path.join(DATA_DIR, 'quantification_filtered_{celltype}.csv.gz'.format(celltype=config['celltype']))
    if normal_data:
        config['normal_data'] = normal_data
    
    _covariates = ' + '.join([c for c in columns if not random_effects or c not in random_effects.replace('(', '').replace(')', '').replace('1', '').replace('|', '').replace(' ', '').split('+')])
    config['design'] = '~ {covariates}{random_effects}'.format(
        covariates=_covariates,
        random_effects='{}{}'.format(' + ' if len(_covariates) != 0 else '', random_effects) if random_effects else ''
    )
    config['columns'] = columns + (['SAMPLE.VISIT'] if 'SAMPLE.VISIT' not in columns else [])
    
    config['splines'] = None 
    config['splines_df'] = None

    config['block_on_donor'] = False
    config['remove_wrong_batch'] = True
    config['remove_exclusions'] = True
    config['remove_300BCG315'] = False
    config['remove_evening'] = False
    config['complete_design'] = False
    config['useful_samples'] = False
    config['save_non_log_CPM'] = False
    config['do_not_correct'] = None

    config['volcano_fdr'] = None
    
    config['effect_size_filter'] = None
    config['rank_metric'] = RANK_METRIC
    config['top_n'] = TOP_N

    config['lola_db_dir'] = LOLA_DB_DIR
    config['lola_db'] = LOLA_DB
    config['lola_collections'] = LOLA_COLLECTIONS
    config['lola_remove_replicates'] = True
    config['lola_metric'] = 'pValueLog'
    config['lola_show_n'] = 20
    config['lola_fdr'] = 0.05

    _pathways = FULL_BCG_PTHW_SET
    _regions = WHICH_REGIONS
    config['enrichr_gene_sets'] = _pathways
    config['enrichr_regions'] = _regions
    config['enrichr_metric'] = 'P-value'
    config['enrichr_show_n'] = 20
    config['enrichr_fdr'] = 0.1
    config['enrichr_db_dir'] = os.path.join(METADATA, 'gene_set_libraries')

    de_dir = make_dir(RESULTS_DIR, 'DE', '{}.{}'.format(config['celltype'], config['model']))
    for d in ['LOLA', 'Enrichr']:
        make_dir(de_dir, d)
    with open(de_fn(config['celltype'], config['model'], data='config', ext='yml', gzipped=False, results_dir=RESULTS_DIR), 'w') as f:
        yaml.dump(config, f, default_flow_style=False, sort_keys=False)
    print(config['counts_fn'])
    print(config['model'])
    print(config['design'])
    print('')
# Out:
# ../metadata/complete_metadata.corrected.csv
# ../data/DE/blood_TSS_enr_corrected_combat_normalized_log2_CPM_PBMC.csv.gz
# varPartTop.batch_TSS_enr_blood_corrected.donor
# ~ (1|SAMPLE.DONOR)

# %% [markdown]
# #### V1 factors - one full model

# %%
celltype = 'PBMC'
annot_fn = SAMPLE_ANNOT_FN.format(which='.corrected')
print(annot_fn)
_annot_df = get_sample_annot(annot_fn)
FACTORS = ['DONOR:AGE', 'DONOR:SEX', 'SAMPLE:VISIT_TIME_REAL', 'DONOR:BMI', 'DONOR:oralContraceptivesIncludingMen', 'SAMPLE:alcoholInLast24h']

config = {}
config['results_dir'] = RESULTS_DIR
config['visits'] = ['V1']
config['debug'] = False
config['batch_corrected'] = False
config['dream'] = False
config['celltype'] = celltype
config['model'] = '{approach}{batch}.FACTORS{blood}.TSS_enr.visit_time'.format(
    approach='V1',
    batch='.batch' if not config['batch_corrected'] else '.batch_corrected',
    blood='.blood' if config['celltype'] == 'PBMC' else ''
)

config['annot_fn'] = annot_fn
config['peak_fn'] = os.path.join(DATA_DIR, 'peaks_filtered_PBMC.csv.gz')
if config['batch_corrected']:
    config['counts_fn'] = os.path.join(DATA_DIR, 'batch_corrected_normalized_log2_CPM_{celltype}.csv.gz'.format(celltype=config['celltype']))
else:
    config['counts_fn'] = os.path.join(DATA_DIR, 'quantification_filtered_{celltype}.csv.gz'.format(celltype=config['celltype']))

_blood = safe_R_name(BLOOD)
_contrasts = [['DONOR.SEXM', 'DONOR.AGE', 'SAMPLE.VISIT_TIME_REAL', 'DONOR.BMI', 'DONOR.oralContraceptivesIncludingMenTrue', 'SAMPLE.alcoholInLast24hTrue']]
_enr_contrasts = _contrasts

config['columns'] = sorted(set(['DONOR.SEX', 'DONOR.AGE', 'SAMPLE.VISIT_TIME_REAL', 'DONOR.BMI', 'DONOR.oralContraceptivesIncludingMen', 'SAMPLE.alcoholInLast24h', 'RUN.TSS_ENRICHMENT'] + \
(['LAB.BATCH'] if not config['batch_corrected'] else []) + \
(_blood if config['celltype'] == 'PBMC' else [])))

config['design'] = '~ {covariates}'.format(covariates=' + '.join(config['columns']))

config['contrasts'] = _contrasts
config['enr_contrasts'] = _enr_contrasts
assert is_iterable(config['contrasts'][0])
assert is_iterable(config['enr_contrasts'][0])

# e.g., "DONOR.IC_DATE_REAL" # this will create "SPLINES" variables - use it in the design
config['splines'] = None 
config['splines_df'] = None

config['block_on_donor'] = False
config['remove_wrong_batch'] = True
config['remove_exclusions'] = True
config['remove_300BCG315'] = False
config['remove_evening'] = False
config['complete_design'] = False
config['useful_samples'] = False
config['save_non_log_CPM'] = False
config['do_not_correct'] = None

config['volcano_fdr'] = [0.05, 0.1, 0.2]

config['effect_size_filter'] = None
config['rank_metric'] = RANK_METRIC
config['top_n'] = TOP_N

config['lola_db_dir'] = LOLA_DB_DIR
config['lola_db'] = LOLA_DB
config['lola_collections'] = LOLA_COLLECTIONS
config['lola_remove_replicates'] = True
config['lola_metric'] = 'pValueLog'
config['lola_show_n'] = 20
config['lola_fdr'] = 0.05

_pathways = FULL_BCG_PTHW_SET
_regions = WHICH_REGIONS
config['enrichr_gene_sets'] = _pathways
config['enrichr_regions'] = _regions
config['enrichr_metric'] = 'P-value'
config['enrichr_show_n'] = 20
config['enrichr_fdr'] = 0.1
config['enrichr_db_dir'] = os.path.join(METADATA, 'gene_set_libraries') 

de_dir = make_dir(RESULTS_DIR, 'DE', '{}.{}'.format(config['celltype'], config['model']))
for d in ['LOLA', 'Enrichr']:
    make_dir(de_dir, d)
with open(de_fn(config['celltype'], config['model'], data='config', ext='yml', gzipped=False, results_dir=RESULTS_DIR), 'w') as f:
    yaml.dump(config, f, default_flow_style=False, sort_keys=False)
print(config['model'])
# Out:
# ../metadata/complete_metadata.corrected.csv
# V1.batch.FACTORS.blood.TSS_enr.visit_time

# %% [markdown]
# #### V1 cytokines and inflammatory markers

# %%
celltype = 'PBMC'
annot_fn = SAMPLE_ANNOT_FN.format(which='.corrected')
_annot_df = get_sample_annot(fn=annot_fn)
print(annot_fn)

for cyto in _annot_df.columns[_annot_df.columns.str.contains('^CYTO:.*_good$|^CM:')]:
    config = {}
    config['results_dir'] = RESULTS_DIR
    config['visits'] = ['V1']
    config['debug'] = False
    config['batch_corrected'] = False
    config['dream'] = False
    config['celltype'] = celltype
    config['model'] = 'V1{batch}{covar}{blood}.TSS_enr.visit_time{cyto}'.format(
        batch='.batch' if not config['batch_corrected'] else '.batch_corrected',
        covar='.sex.age{}'.format('.bmi.oralContra' if 'CM:' in cyto else ''),
        blood='.blood' if config['celltype'] == 'PBMC' else '',
        cyto='.{}'.format(safe_R_name(cyto))
    )
        
    config['annot_fn'] = annot_fn
    config['peak_fn'] = os.path.join(DATA_DIR, 'peaks_filtered_PBMC.csv.gz')
    if config['batch_corrected']:
        config['counts_fn'] = os.path.join(DATA_DIR, 'batch_corrected_normalized_log2_CPM_{celltype}.csv.gz'.format(celltype=config['celltype']))
    else:
        config['counts_fn'] = os.path.join(DATA_DIR, 'quantification_filtered_{celltype}.csv.gz'.format(celltype=config['celltype']))
    
    _contrasts = [[safe_R_name(cyto)]]
    _enr_contrasts = _contrasts
    _blood = safe_R_name(BLOOD)

    config['columns'] = sorted(set([safe_R_name(cyto), 'DONOR.SEX', 'DONOR.AGE', 'RUN.TSS_ENRICHMENT', 'SAMPLE.VISIT_TIME_REAL'] + \
    (['LAB.BATCH'] if not config['batch_corrected'] else []) + \
    (_blood if config['celltype'] == 'PBMC' else []) + \
    (['DONOR.BMI', 'DONOR.oralContraceptivesIncludingMen'] if 'CM:' in cyto else [])))

    config['design'] = '~ {covariates}'.format(covariates=' + '.join(config['columns']))

    config['contrasts'] = _contrasts
    config['enr_contrasts'] = _enr_contrasts
    assert is_iterable(config['contrasts'][0])
    assert is_iterable(config['enr_contrasts'][0])

    # e.g., "DONOR.IC_DATE_REAL" # this will create "SPLINES" variables - use it in the design
    config['splines'] = None 
    config['splines_df'] = None

    config['block_on_donor'] = False
    config['remove_wrong_batch'] = True
    config['remove_exclusions'] = True
    config['remove_300BCG315'] = False
    config['remove_evening'] = False
    config['complete_design'] = False
    config['useful_samples'] = False
    config['save_non_log_CPM'] = False
    config['do_not_correct'] = [safe_R_name(cyto)]

    config['volcano_fdr'] = [0.05, 0.1, 0.2]

    config['effect_size_filter'] = None
    config['rank_metric'] = RANK_METRIC
    config['top_n'] = TOP_N

    config['lola_db_dir'] = LOLA_DB_DIR
    config['lola_db'] = LOLA_DB
    config['lola_collections'] = LOLA_COLLECTIONS
    config['lola_remove_replicates'] = True
    config['lola_metric'] = 'pValueLog'
    config['lola_show_n'] = 20
    config['lola_fdr'] = 0.05

    _pathways = FULL_BCG_PTHW_SET
    _regions = WHICH_REGIONS
    config['enrichr_gene_sets'] = _pathways
    config['enrichr_regions'] = _regions
    config['enrichr_metric'] = 'P-value'
    config['enrichr_show_n'] = 20
    config['enrichr_fdr'] = 0.1
    config['enrichr_db_dir'] = os.path.join(METADATA, 'gene_set_libraries') 

    de_dir = make_dir(RESULTS_DIR, 'DE', '{}.{}'.format(config['celltype'], config['model']))
    for d in ['LOLA', 'Enrichr']:
        make_dir(de_dir, d)
    with open(de_fn(config['celltype'], config['model'], data='config', ext='yml', gzipped=False, results_dir=RESULTS_DIR), 'w') as f:
        yaml.dump(config, f, default_flow_style=False, sort_keys=False)
    print(config['model'])
# Out:
# ../metadata/complete_metadata.corrected.csv
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.ADA_P00813
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.AXIN1_O15169
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.Beta.NGF_P01138
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CASP.8_Q14790
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CCL11_P51671
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CCL19_Q99731
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CCL20_P78556
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CCL23_P55773
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CCL25_O15444
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CCL28_Q9NRJ3
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CCL3_P10147
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CCL4_P13236
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CD244_Q9BZW8
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CD40_P25942
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CD5_P06127
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CD6_Q8WWJ7
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CD8A_P01732
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CDCP1_Q9H5V8
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CSF.1_P09603
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CST5_P28325
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CX3CL1_P78423
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CXCL10_P02778
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CXCL11_O14625
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CXCL1_P09341
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CXCL5_P42830
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CXCL6_P80162
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.CXCL9_Q07325
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.DNER_Q8NFT8
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.EN.RAGE_P80511
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.FGF.19_O95750
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.FGF.21_Q9NSA1
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.FGF.23_Q9GZV9
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.Flt3L_P49771
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.GDNF_P39905
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.HGF_P14210
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.IL.10RA_Q13651
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.IL.10RB_Q08334
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.IL.12B_P29460
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.IL.17A_Q16552
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.IL.17C_Q9P0M4
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.IL.18R1_Q13478
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.IL10_P22301
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.IL18_Q14116
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.IL6_P05231
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.IL7_P13232
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.IL8_P10145
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.LAP.TGF.beta.1_P01137
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.LIF.R_P42702
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.MCP.1_P13500
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.MCP.2_P80075
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.MCP.3_P80098
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.MCP.4_Q99616
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.MMP.10_P09238
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.MMP.1_P03956
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.NT.3_P20783
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.OPG_O00300
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.OSM_P13725
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.PD.L1_Q9NZQ7
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.SCF_P21583
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.SIRT2_Q8IXJ6
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.SLAMF1_Q13291
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.ST1A1_P50225
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.STAMPB_O95630
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.TGF.alpha_P01135
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.TNFB_P01374
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.TNFRSF9_Q07011
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.TNFSF14_O43557
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.TRAIL_P50591
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.TRANCE_O14788
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.TWEAK_O43508
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.VEGFA_P15692
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.XE.BP1_Q13541
# V1.batch.sex.age.bmi.oralContra.blood.TSS_enr.visit_time.CM.uPA_P00749
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.C.albicans.yeast_24h_PBMC_GMCSF_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.C.albicans.yeast_24h_PBMC_IL.10_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.C.albicans.yeast_24h_PBMC_IL.1b_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.C.albicans.yeast_24h_PBMC_IL.1ra_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.C.albicans.yeast_24h_PBMC_IL.2R_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.C.albicans.yeast_24h_PBMC_IL.6_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.C.albicans.yeast_24h_PBMC_IP10_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.C.albicans.yeast_24h_PBMC_MIG_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.C.albicans.yeast_24h_PBMC_MIP1a_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.C.albicans.yeast_24h_PBMC_MIP1b_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.C.albicans.yeast_24h_PBMC_TNF.a_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.C.albicans.yeast_24h_PBMC_lactate_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.C.albicans.yeast_7d_PBMC_IL.17_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.LPS.100ng_24h_PBMC_IL.1b_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.LPS.100ng_24h_PBMC_IL.6_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.LPS.100ng_24h_PBMC_TNF.a_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.MTB_24h_PBMC_IL.10_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.MTB_24h_PBMC_IL.12_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.MTB_24h_PBMC_IL.1b_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.MTB_24h_PBMC_IL.1ra_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.MTB_24h_PBMC_IL.6_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.MTB_24h_PBMC_MIP1a_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.MTB_24h_PBMC_MIP1b_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.MTB_24h_PBMC_lactate_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.MTB_7d_PBMC_IFNg_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.MTB_7d_PBMC_IL.17_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.S.aureus_24h_PBMC_IL.1b_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.S.aureus_24h_PBMC_IL.6_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.S.aureus_24h_PBMC_TNF.a_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.CYTO.S.aureus_7d_PBMC_IFNg_good

# %% [markdown]
# #### Seasonal changes in ATAC-seq

# %%
celltype = 'PBMC'
annot_fn = SAMPLE_ANNOT_FN.format(which='.corrected')
print(annot_fn)
_annot_df = get_sample_annot(annot_fn)
COEFS = pd.read_csv(os.path.join(METADATA, 'selected_factors.csv'), comment='#', header=None)[0]
COEFS = COEFS[COEFS.str.contains('^DONOR:')].tolist()

for factor in ['season'] + COEFS:
        config = {}
        config['results_dir'] = RESULTS_DIR
        config['debug'] = False
        config['batch_corrected'] = factor == 'season'
        config['dream'] = False
        config['celltype'] = celltype
        config['model'] = 'fixed.{approach}{batch}.sex.age{blood}.TSS_enr.visit_time{factor}_interaction'.format(
            approach='donor_as_mixed',
            batch='.batch' if not config['batch_corrected'] else '.batch_corrected',
            blood='.blood' if config['celltype'] == 'PBMC' else '',
            factor='.{}'.format(safe_R_name(factor)) if factor else ''
        )

        config['annot_fn'] = annot_fn
        config['peak_fn'] = os.path.join(DATA_DIR, 'peaks_filtered_PBMC.csv.gz')
        if config['batch_corrected']:
            config['counts_fn'] = os.path.join(DATA_DIR, 'batch_corrected_normalized_log2_CPM_{celltype}.csv.gz'.format(celltype=config['celltype']))
        else:
            config['counts_fn'] = os.path.join(DATA_DIR, 'quantification_filtered_{celltype}.csv.gz'.format(celltype=config['celltype']))

        if factor == 'season':
            # don't ask me
            _contrasts = [['DONOR.IC_DATE_2PI_SIN.{}'.format(visit),
                           '{}.DONOR.IC_DATE_2PI_COS'.format(visit)] for visit in ['V2', 'V3']] + \
                         [['V2', 'V3'],
                          ['SAMPLE.VISIT_DATE_2PI_SIN', 'SAMPLE.VISIT_DATE_2PI_COS']]
        else:
            _contrasts = [['{}{}.{}'.format(
                safe_R_name(factor),
                'True' if is_bool_dtype(_annot_df[factor].dtype) else 'M' if factor == 'DONOR:SEX' else '',
                visit
            ) for visit in ['V2', 'V3']]]
        _enr_contrasts = _contrasts
        
        _blood = safe_R_name(BLOOD)
        config['columns'] = sorted(set(['SAMPLE.DONOR', 'SAMPLE.VISIT', 'SAMPLE.VISIT_TIME_REAL', 'DONOR.IC_TIME_REAL', 'DONOR.SEX', 'DONOR.AGE', 'RUN.TSS_ENRICHMENT'] + \
        (['LAB.BATCH'] if not config['batch_corrected'] else []) + \
        (_blood if config['celltype'] == 'PBMC' else []) + \
        (['DONOR.IC_DATE_2PI_SIN', 'DONOR.IC_DATE_2PI_COS', 'SAMPLE.VISIT_DATE_2PI_SIN', 'SAMPLE.VISIT_DATE_2PI_COS'] if factor == 'season' else \
         [safe_R_name(factor), safe_R_name(factor.replace('DONOR:IC_TIME', 'SAMPLE:VISIT_TIME').replace('DONOR:IC_', 'SAMPLE:'))] \
         if factor and factor.startswith('DONOR:IC_') else [safe_R_name(factor)] if factor else []
        )))

        if factor == 'season':
            config['design'] = '~ DONOR.IC_DATE_2PI_SIN * SAMPLE.VISIT + DONOR.IC_DATE_2PI_COS * SAMPLE.VISIT + {covariates}'.format(
                covariates=' + '.join([c for c in config['columns'] if c not in ['SAMPLE.DONOR', 'DONOR.IC_TIME_REAL', 'SAMPLE.VISIT', 'DONOR.IC_DATE_2PI_SIN', 'DONOR.IC_DATE_2PI_COS']]))
        else:
            config['design'] = '~ {factor} * SAMPLE.VISIT + {covariates}'.format(
                factor=safe_R_name(factor), covariates=' + '.join([c for c in config['columns'] if c not in ['SAMPLE.DONOR', 'DONOR.IC_TIME_REAL', 'SAMPLE.VISIT', safe_R_name(factor)]]))
        config['contrasts'] = _contrasts
        config['enr_contrasts'] = _enr_contrasts
        assert is_iterable(config['contrasts'][0])
        assert is_iterable(config['enr_contrasts'][0])

        # e.g., "DONOR.IC_DATE_REAL" # this will create "SPLINES" variables - use it in the design
        config['splines'] = None 
        config['splines_df'] = None
        
        if factor == 'season':
            config['drop_cols'] = ['DONOR.IC_DATE_2PI_SIN', 'DONOR.IC_DATE_2PI_COS']
        elif factor.startswith('DONOR:IC_'):
            continue
            config['drop_cols'] = ['{}{}'.format(safe_R_name(factor),
                                                 'True' if is_bool_dtype(_annot_df[factor].dtype) else 'M' if factor == 'DONOR:SEX' else '')]
        else:
            continue

        print(config['model'])
        
        config['block_on_donor'] = True
        config['remove_wrong_batch'] = True
        config['remove_exclusions'] = True
        config['remove_300BCG315'] = False
        config['remove_evening'] = True
        config['complete_design'] = False
        config['useful_samples'] = False
        config['save_non_log_CPM'] = False
        config['do_not_correct'] = None

        config['volcano_fdr'] = [0.05, 0.1, 0.2]

        config['effect_size_filter'] = None
        config['rank_metric'] = RANK_METRIC
        config['top_n'] = TOP_N

        config['lola_db_dir'] = LOLA_DB_DIR
        config['lola_db'] = LOLA_DB
        config['lola_collections'] = LOLA_COLLECTIONS
        config['lola_remove_replicates'] = True
        config['lola_metric'] = 'pValueLog'
        config['lola_show_n'] = 20
        config['lola_fdr'] = 0.05

        _pathways = FULL_BCG_PTHW_SET
        _regions = WHICH_REGIONS
        config['enrichr_gene_sets'] = _pathways
        config['enrichr_regions'] = _regions
        config['enrichr_metric'] = 'P-value'
        config['enrichr_show_n'] = 20
        config['enrichr_fdr'] = 0.1
        config['enrichr_db_dir'] = os.path.join(METADATA, 'gene_set_libraries') 

        de_dir = make_dir(RESULTS_DIR, 'DE', '{}.{}'.format(config['celltype'], config['model']))
        for d in ['LOLA', 'Enrichr']:
            make_dir(de_dir, d)
        with open(de_fn(config['celltype'], config['model'], data='config', ext='yml', gzipped=False, results_dir=RESULTS_DIR), 'w') as f:
            yaml.dump(config, f, default_flow_style=False, sort_keys=False)
# Out:
# ../metadata/complete_metadata.corrected.csv
# fixed.donor_as_mixed.batch_corrected.sex.age.blood.TSS_enr.visit_time.season_interaction

# %% [markdown]
# #### V3 cytokine fold changes

# %%
celltype = 'PBMC'
annot_fn = SAMPLE_ANNOT_FN.format(which='.corrected')
_annot_df = get_sample_annot(fn=annot_fn)
print(annot_fn)

for visit in ['V3', 'V2']:
    for cyto in _annot_df.columns[_annot_df.columns.str.contains('^LFC_{visit}_CORR_CYTO:.*_good'.format(visit=visit))]:
        config = {}
        config['results_dir'] = RESULTS_DIR
        config['visits'] = ['V1']
        config['debug'] = False
        config['batch_corrected'] = False
        config['dream'] = False
        config['celltype'] = celltype
        config['model'] = 'V1{batch}{covar}{blood}.TSS_enr.visit_time{cyto}'.format(
            batch='.batch' if not config['batch_corrected'] else '.batch_corrected',
            covar='.sex.age{}'.format('.bmi.oralContra' if '_CORR_CM:' in cyto else ''),
            blood='.blood' if config['celltype'] == 'PBMC' else '',
            cyto='.{}'.format(safe_R_name(cyto))
        )

        config['annot_fn'] = annot_fn
        config['peak_fn'] = os.path.join(DATA_DIR, 'peaks_filtered_PBMC.csv.gz')
        if config['batch_corrected']:
            config['counts_fn'] = os.path.join(DATA_DIR, 'batch_corrected_normalized_log2_CPM_{celltype}.csv.gz'.format(celltype=config['celltype']))
        else:
            config['counts_fn'] = os.path.join(DATA_DIR, 'quantification_filtered_{celltype}.csv.gz'.format(celltype=config['celltype']))

        _contrasts = [[safe_R_name(cyto)]]
        _enr_contrasts = _contrasts
        _blood = safe_R_name(BLOOD)

        config['columns'] = sorted(set([safe_R_name(cyto), 'DONOR.SEX', 'DONOR.AGE', 'RUN.TSS_ENRICHMENT', 'SAMPLE.VISIT_TIME_REAL'] + \
        (['LAB.BATCH'] if not config['batch_corrected'] else []) + \
        (_blood if config['celltype'] == 'PBMC' else []) + \
        (['DONOR.BMI', 'DONOR.oralContraceptivesIncludingMen'] if '_CORR_CM:' in cyto else [])))

        config['design'] = '~ {covariates}'.format(covariates=' + '.join(config['columns']))

        config['contrasts'] = _contrasts
        config['enr_contrasts'] = _enr_contrasts
        assert is_iterable(config['contrasts'][0])
        assert is_iterable(config['enr_contrasts'][0])

        # e.g., "DONOR.IC_DATE_REAL" # this will create "SPLINES" variables - use it in the design
        config['splines'] = None 
        config['splines_df'] = None

        config['block_on_donor'] = False
        config['remove_wrong_batch'] = True
        config['remove_exclusions'] = True
        config['remove_300BCG315'] = False
        config['remove_evening'] = False
        config['complete_design'] = False
        config['useful_samples'] = False
        config['save_non_log_CPM'] = False
        config['do_not_correct'] = [safe_R_name(cyto)]

        config['volcano_fdr'] = [0.05, 0.1, 0.2]

        config['effect_size_filter'] = None
        config['rank_metric'] = RANK_METRIC
        config['top_n'] = TOP_N

        config['lola_db_dir'] = LOLA_DB_DIR
        config['lola_db'] = LOLA_DB
        config['lola_collections'] = LOLA_COLLECTIONS
        config['lola_remove_replicates'] = True
        config['lola_metric'] = 'pValueLog'
        config['lola_show_n'] = 20
        config['lola_fdr'] = 0.05

        _pathways = FULL_BCG_PTHW_SET
        _regions = WHICH_REGIONS
        config['enrichr_gene_sets'] = _pathways
        config['enrichr_regions'] = _regions
        config['enrichr_metric'] = 'P-value'
        config['enrichr_show_n'] = 20
        config['enrichr_fdr'] = 0.1
        config['enrichr_db_dir'] = os.path.join(METADATA, 'gene_set_libraries') 

        de_dir = make_dir(RESULTS_DIR, 'DE', '{}.{}'.format(config['celltype'], config['model']))
        for d in ['LOLA', 'Enrichr']:
            make_dir(de_dir, d)
        with open(de_fn(config['celltype'], config['model'], data='config', ext='yml', gzipped=False, results_dir=RESULTS_DIR), 'w') as f:
            yaml.dump(config, f, default_flow_style=False, sort_keys=False)
        print(config['model'])
# Out:
# ../metadata/complete_metadata.corrected.csv
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.C.albicans.yeast_24h_PBMC_GMCSF_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.C.albicans.yeast_24h_PBMC_IL.10_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.C.albicans.yeast_24h_PBMC_IL.1b_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.C.albicans.yeast_24h_PBMC_IL.1ra_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.C.albicans.yeast_24h_PBMC_IL.2R_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.C.albicans.yeast_24h_PBMC_IL.6_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.C.albicans.yeast_24h_PBMC_IP10_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.C.albicans.yeast_24h_PBMC_MIG_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.C.albicans.yeast_24h_PBMC_MIP1a_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.C.albicans.yeast_24h_PBMC_MIP1b_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.C.albicans.yeast_24h_PBMC_TNF.a_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.C.albicans.yeast_24h_PBMC_lactate_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.C.albicans.yeast_7d_PBMC_IL.17_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.LPS.100ng_24h_PBMC_IL.1b_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.LPS.100ng_24h_PBMC_IL.6_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.LPS.100ng_24h_PBMC_TNF.a_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.MTB_24h_PBMC_IL.10_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.MTB_24h_PBMC_IL.12_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.MTB_24h_PBMC_IL.1b_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.MTB_24h_PBMC_IL.1ra_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.MTB_24h_PBMC_IL.6_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.MTB_24h_PBMC_MIP1a_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.MTB_24h_PBMC_MIP1b_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.MTB_24h_PBMC_lactate_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.MTB_7d_PBMC_IFNg_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.MTB_7d_PBMC_IL.17_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.S.aureus_24h_PBMC_IL.1b_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.S.aureus_24h_PBMC_IL.6_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.S.aureus_24h_PBMC_TNF.a_good
# V1.batch.sex.age.blood.TSS_enr.visit_time.LFC_V2_CORR_CYTO.S.aureus_7d_PBMC_IFNg_good

# %% [markdown]
# #### Vaccination PBMC

# %%
celltype = 'PBMC'
annot_fn = SAMPLE_ANNOT_FN.format(which='.corrected')
print(annot_fn)
for suffix in ['_FC1.2_responder']:
    for donor_score_col in [
        'thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3',
        'thm.adaptive_MTB_7d_V3',
        'thm.heterologous_nonspecific_7d_V3',
    ]:
        _annot_df = get_sample_annot(annot_fn)
        assert (donor_score_col if not suffix else '{}{}'.format(donor_score_col, suffix)) in _annot_df.columns, donor_score_col

        config = {}
        config['results_dir'] = RESULTS_DIR
        config['debug'] = False
        config['batch_corrected'] = False
        config['dream'] = False

        config['celltype'] = celltype
        config['model'] = '{approach}.batch.sex.age{blood}.TSS_enr.visit_time.{score}{suffix}'.format(
            approach='dream' if config['dream'] else 'donor_as_mixed',\
            blood='.blood' if config['celltype'] == 'PBMC' else '',
            score=donor_score_col,
            suffix=suffix)

        config['annot_fn'] = annot_fn
        config['peak_fn'] = os.path.join(DATA_DIR, 'peaks_filtered_PBMC.csv.gz')
        config['counts_fn'] = os.path.join(DATA_DIR, 'quantification_filtered_{celltype}.csv.gz'.format(celltype=config['celltype']))

        if not suffix:
            _score = safe_R_name(donor_score_col)
            _interaction = '{score}*SAMPLE.VISIT'.format(score=_score)
            _contrasts = [[_score, 'V2', 'V3', '{}.V2'.format(_score), '{}.V3'.format(_score)]]
            _enr_contrasts = _contrasts
        else:
            _score = '{}{}'.format(safe_R_name(donor_score_col), safe_R_name(suffix))
            _interaction = '{score} + {score}:SAMPLE.VISIT'.format(score=_score)
            if config['dream']:
                _contrasts = [['{}{}R'.format(safe_R_name(donor_score_col), safe_R_name(suffix)),
                               '{}{}N:SAMPLE.VISITV2'.format(safe_R_name(donor_score_col), safe_R_name(suffix)),
                               '{}{}N:SAMPLE.VISITV3'.format(safe_R_name(donor_score_col), safe_R_name(suffix)),
                               '{}{}R:SAMPLE.VISITV2'.format(safe_R_name(donor_score_col), safe_R_name(suffix)),
                               '{}{}R:SAMPLE.VISITV3'.format(safe_R_name(donor_score_col), safe_R_name(suffix)),
                              ]]
            else:
                _contrasts = [['{}{}R'.format(safe_R_name(donor_score_col), safe_R_name(suffix.replace('_responder', '_'))),
                               '{}{}N.V2'.format(safe_R_name(donor_score_col), safe_R_name(suffix.replace('_responder', '_'))),
                               '{}{}N.V3'.format(safe_R_name(donor_score_col), safe_R_name(suffix.replace('_responder', '_'))),
                               '{}{}R.V2'.format(safe_R_name(donor_score_col), safe_R_name(suffix.replace('_responder', '_'))),
                               '{}{}R.V3'.format(safe_R_name(donor_score_col), safe_R_name(suffix.replace('_responder', '_'))),
                              ]]
            _enr_contrasts = _contrasts

        _blood = safe_R_name(BLOOD)
        config['columns'] = ['SAMPLE.DONOR', 'SAMPLE.VISIT', 'DONOR.SEX', 'DONOR.AGE',
                             'RUN.TSS_ENRICHMENT', 'SAMPLE.VISIT_TIME_REAL', 'LAB.BATCH'] + \
        (_blood if config['celltype'] == 'PBMC' else []) + \
        [_score]

        config['design'] = '~ {interaction} + {covariates}'.format(
            interaction=_interaction,
            covariates=' + '.join(
                [c for c in config['columns'] if c not in [_score, 'SAMPLE.VISIT', 'SAMPLE.DONOR']]))

        config['contrasts'] = _contrasts
        config['enr_contrasts'] = [[c for c in _contrasts[0] if c.endswith('_R') or c.endswith('_R.V2') or c.endswith('_R.V3')]]
        assert is_iterable(config['contrasts'][0])
        assert is_iterable(config['enr_contrasts'][0])

        # e.g., "DONOR.IC_DATE_REAL" # this will create "SPLINES" variables - use it in the design
        config['splines'] = None 
        config['splines_df'] = None

        config['block_on_donor'] = True
        config['remove_wrong_batch'] = True
        config['remove_exclusions'] = True
        config['remove_300BCG315'] = False
        config['remove_evening'] = False
        config['complete_design'] = False
        config['useful_samples'] = False
        config['save_non_log_CPM'] = False
        config['do_not_correct'] = ['V2', 'V3']

        config['volcano_fdr'] = [0.05, 0.1, 0.2]

        config['effect_size_filter'] = None
        config['rank_metric'] = RANK_METRIC
        config['top_n'] = TOP_N

        config['lola_db_dir'] = LOLA_DB_DIR
        config['lola_db'] = LOLA_DB
        config['lola_collections'] = LOLA_COLLECTIONS
        config['lola_remove_replicates'] = True
        config['lola_metric'] = 'pValueLog'
        config['lola_show_n'] = 20
        config['lola_fdr'] = 0.05

        _pathways = FULL_BCG_PTHW_SET
        _regions = WHICH_REGIONS
        config['enrichr_gene_sets'] = _pathways
        config['enrichr_regions'] = _regions
        config['enrichr_metric'] = 'P-value'
        config['enrichr_show_n'] = 20
        config['enrichr_fdr'] = 0.1
        config['enrichr_db_dir'] = os.path.join(METADATA, 'gene_set_libraries') 

        de_dir = make_dir(RESULTS_DIR, 'DE', '{}.{}'.format(config['celltype'], config['model']))
        for d in ['LOLA', 'Enrichr']:
            make_dir(de_dir, d)
        with open(de_fn(config['celltype'], config['model'], data='config', ext='yml', gzipped=False, results_dir=RESULTS_DIR), 'w') as f:
            yaml.dump(config, f, default_flow_style=False, sort_keys=False)
        print(config['model'])
# Out:
# ../metadata/complete_metadata.corrected.csv
# donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.adaptive_MTB_7d_V3_FC1.2_responder
# donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.heterologous_nonspecific_7d_V3_FC1.2_responder

# %% [markdown]
# ### Bootstraps

# %%
DEBUG = False
celltype = 'PBMC'
annot_fn = SAMPLE_ANNOT_FN.format(which='.corrected')
print(annot_fn)
for suffix in ['_FC1.2_responder']:
    for donor_score_col in [
        'thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3',
        # 'thm.adaptive_MTB_7d_V3',
        # 'thm.heterologous_nonspecific_7d_V3',
    ]:
        for seed in range(101, 1001):
            _annot_df = get_sample_annot(annot_fn)
            assert (donor_score_col if not suffix else '{}{}'.format(donor_score_col, suffix)) in _annot_df.columns, donor_score_col

            config = {}
            config['results_dir'] = RESULTS_DIR
            config['bootstrap'] = seed
            config['debug'] = DEBUG
            config['batch_corrected'] = False
            config['dream'] = False

            config['celltype'] = celltype
            config['model'] = 'BS{bootstrap}.{approach}.batch.sex.age{blood}.TSS_enr.visit_time.{score}{suffix}'.format(
                bootstrap=seed,
                approach='dream' if config['dream'] else 'donor_as_mixed',\
                blood='.blood' if config['celltype'] == 'PBMC' else '',
                score=donor_score_col,
                suffix=suffix)

            config['annot_fn'] = annot_fn
            config['peak_fn'] = os.path.join(DATA_DIR, 'peaks_filtered_PBMC.csv.gz')
            config['counts_fn'] = os.path.join(DATA_DIR, 'quantification_filtered_{celltype}.csv.gz'.format(celltype=config['celltype']))

            if not suffix:
                _score = safe_R_name(donor_score_col)
                _interaction = '{score}*SAMPLE.VISIT'.format(score=_score)
                _contrasts = [[_score, 'V2', 'V3', '{}.V2'.format(_score), '{}.V3'.format(_score)]]
                _enr_contrasts = _contrasts
            else:
                _score = '{}{}'.format(safe_R_name(donor_score_col), safe_R_name(suffix))
                _interaction = '{score} + {score}:SAMPLE.VISIT'.format(score=_score)
                if config['dream']:
                    _contrasts = [['{}{}R'.format(safe_R_name(donor_score_col), safe_R_name(suffix)),
                                   '{}{}N:SAMPLE.VISITV2'.format(safe_R_name(donor_score_col), safe_R_name(suffix)),
                                   '{}{}N:SAMPLE.VISITV3'.format(safe_R_name(donor_score_col), safe_R_name(suffix)),
                                   '{}{}R:SAMPLE.VISITV2'.format(safe_R_name(donor_score_col), safe_R_name(suffix)),
                                   '{}{}R:SAMPLE.VISITV3'.format(safe_R_name(donor_score_col), safe_R_name(suffix)),
                                  ]]
                else:
                    _contrasts = [['{}{}R'.format(safe_R_name(donor_score_col), safe_R_name(suffix.replace('_responder', '_'))),
                                   '{}{}N.V2'.format(safe_R_name(donor_score_col), safe_R_name(suffix.replace('_responder', '_'))),
                                   '{}{}N.V3'.format(safe_R_name(donor_score_col), safe_R_name(suffix.replace('_responder', '_'))),
                                   '{}{}R.V2'.format(safe_R_name(donor_score_col), safe_R_name(suffix.replace('_responder', '_'))),
                                   '{}{}R.V3'.format(safe_R_name(donor_score_col), safe_R_name(suffix.replace('_responder', '_'))),
                                  ]]
                _enr_contrasts = _contrasts

            _blood = safe_R_name(BLOOD)
            config['columns'] = ['SAMPLE.DONOR', 'SAMPLE.VISIT', 'DONOR.SEX', 'DONOR.AGE',
                                 'RUN.TSS_ENRICHMENT', 'SAMPLE.VISIT_TIME_REAL', 'LAB.BATCH'] + \
            (_blood if config['celltype'] == 'PBMC' else []) + \
            [_score]

            config['design'] = '~ {interaction} + {covariates}'.format(
                interaction=_interaction,
                covariates=' + '.join(
                    [c for c in config['columns'] if c not in [_score, 'SAMPLE.VISIT', 'SAMPLE.DONOR']]))

            config['contrasts'] = _contrasts
            config['enr_contrasts'] = [[c for c in _contrasts[0] if c.endswith('_R') or c.endswith('_R.V2') or c.endswith('_R.V3')]]
            assert is_iterable(config['contrasts'][0])
            assert is_iterable(config['enr_contrasts'][0])

            # e.g., "DONOR.IC_DATE_REAL" # this will create "SPLINES" variables - use it in the design
            config['splines'] = None 
            config['splines_df'] = None

            config['block_on_donor'] = True
            config['remove_wrong_batch'] = True
            config['remove_exclusions'] = True
            config['remove_300BCG315'] = False
            config['remove_evening'] = False
            config['complete_design'] = False
            config['useful_samples'] = False
            config['save_non_log_CPM'] = False
            config['do_not_correct'] = ['V2', 'V3']

            config['volcano_fdr'] = [0.05, 0.1, 0.2]

            config['effect_size_filter'] = None
            config['rank_metric'] = RANK_METRIC
            config['top_n'] = TOP_N

            config['lola_db_dir'] = LOLA_DB_DIR
            config['lola_db'] = LOLA_DB
            config['lola_collections'] = LOLA_COLLECTIONS
            config['lola_remove_replicates'] = True
            config['lola_metric'] = 'pValueLog'
            config['lola_show_n'] = 20
            config['lola_fdr'] = 0.05

            _pathways = FULL_BCG_PTHW_SET
            _regions = WHICH_REGIONS
            config['enrichr_gene_sets'] = _pathways
            config['enrichr_regions'] = _regions
            config['enrichr_metric'] = 'P-value'
            config['enrichr_show_n'] = 20
            config['enrichr_fdr'] = 0.1
            config['enrichr_db_dir'] = os.path.join(METADATA, 'gene_set_libraries') 

            de_dir = make_dir(RESULTS_DIR, 'DE', f'{config["celltype"]}.{config["model"]}')
            for d in ['LOLA', 'Enrichr']:
                make_dir(de_dir, d)
            with open(de_fn(config['celltype'], config['model'], data='config', ext='yml', gzipped=False, results_dir=RESULTS_DIR), 'w') as f:
                yaml.dump(config, f, default_flow_style=False, sort_keys=False)
            print(config['model'])
# Out:
# ../metadata/complete_metadata.corrected.csv
# BS101.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS102.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS103.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS104.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS105.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS106.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS107.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS108.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS109.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS110.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS111.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS112.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS113.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS114.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS115.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS116.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS117.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS118.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS119.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS120.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS121.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS122.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS123.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS124.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS125.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS126.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS127.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS128.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS129.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS130.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS131.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS132.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS133.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS134.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS135.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS136.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS137.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS138.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS139.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS140.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS141.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS142.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS143.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS144.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS145.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS146.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS147.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS148.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS149.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS150.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS151.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS152.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS153.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS154.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS155.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS156.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS157.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS158.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS159.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS160.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS161.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS162.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS163.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS164.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS165.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS166.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS167.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS168.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS169.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS170.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS171.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS172.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS173.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS174.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS175.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS176.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS177.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS178.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS179.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS180.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS181.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS182.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS183.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS184.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS185.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS186.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS187.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS188.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS189.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS190.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS191.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS192.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS193.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS194.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS195.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS196.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS197.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS198.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS199.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS200.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS201.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS202.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS203.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS204.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS205.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS206.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS207.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS208.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS209.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS210.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS211.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS212.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS213.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS214.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS215.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS216.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS217.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS218.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS219.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS220.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS221.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS222.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS223.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS224.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS225.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS226.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS227.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS228.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS229.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS230.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS231.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS232.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS233.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS234.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS235.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS236.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS237.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS238.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS239.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS240.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS241.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS242.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS243.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS244.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS245.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS246.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS247.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS248.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS249.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS250.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS251.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS252.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS253.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS254.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS255.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS256.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS257.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS258.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS259.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS260.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS261.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS262.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS263.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS264.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS265.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS266.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS267.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS268.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS269.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS270.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS271.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS272.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS273.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS274.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS275.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS276.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS277.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS278.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS279.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS280.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS281.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS282.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS283.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS284.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS285.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS286.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS287.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS288.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS289.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS290.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS291.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS292.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS293.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS294.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS295.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS296.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS297.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS298.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS299.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS300.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS301.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS302.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS303.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS304.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS305.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS306.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS307.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS308.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS309.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS310.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS311.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS312.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS313.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS314.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS315.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS316.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS317.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS318.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS319.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS320.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS321.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS322.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS323.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS324.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS325.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS326.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS327.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS328.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS329.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS330.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS331.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS332.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS333.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS334.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS335.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS336.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS337.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS338.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS339.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS340.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS341.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS342.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS343.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS344.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS345.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS346.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS347.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS348.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS349.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS350.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS351.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS352.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS353.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS354.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS355.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS356.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS357.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS358.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS359.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS360.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS361.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS362.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS363.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS364.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS365.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS366.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS367.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS368.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS369.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS370.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS371.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS372.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS373.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS374.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS375.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS376.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS377.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS378.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS379.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS380.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS381.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS382.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS383.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS384.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS385.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS386.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS387.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS388.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS389.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS390.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS391.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS392.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS393.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS394.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS395.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS396.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS397.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS398.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS399.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS400.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS401.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS402.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS403.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS404.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS405.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS406.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS407.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS408.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS409.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS410.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS411.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS412.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS413.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS414.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS415.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS416.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS417.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS418.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS419.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS420.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS421.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS422.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS423.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS424.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS425.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS426.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS427.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS428.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS429.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS430.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS431.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS432.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS433.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS434.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS435.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS436.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS437.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS438.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS439.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS440.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS441.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS442.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS443.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS444.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS445.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS446.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS447.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS448.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS449.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS450.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS451.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS452.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS453.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS454.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS455.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS456.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS457.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS458.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS459.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS460.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS461.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS462.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS463.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS464.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS465.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS466.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS467.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS468.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS469.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS470.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS471.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS472.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS473.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS474.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS475.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS476.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS477.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS478.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS479.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS480.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS481.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS482.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS483.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS484.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS485.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS486.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# ...
# BS872.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS873.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS874.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS875.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS876.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS877.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS878.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS879.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS880.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS881.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS882.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS883.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS884.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS885.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS886.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS887.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS888.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS889.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS890.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS891.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS892.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS893.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS894.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS895.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS896.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS897.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS898.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS899.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS900.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS901.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS902.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS903.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS904.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS905.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS906.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS907.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS908.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS909.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS910.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS911.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS912.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS913.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS914.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS915.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS916.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS917.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS918.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS919.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS920.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS921.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS922.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS923.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS924.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS925.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS926.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS927.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS928.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS929.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS930.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS931.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS932.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS933.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS934.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS935.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS936.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS937.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS938.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS939.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS940.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS941.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS942.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS943.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS944.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS945.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS946.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS947.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS948.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS949.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS950.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS951.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS952.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS953.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS954.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS955.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS956.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS957.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS958.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS959.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS960.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS961.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS962.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS963.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS964.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS965.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS966.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS967.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS968.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS969.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS970.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS971.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS972.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS973.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS974.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS975.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS976.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS977.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS978.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS979.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS980.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS981.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS982.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS983.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS984.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS985.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS986.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS987.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS988.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS989.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS990.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS991.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS992.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS993.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS994.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS995.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS996.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS997.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS998.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS999.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
# BS1000.donor_as_mixed.batch.sex.age.blood.TSS_enr.visit_time.thm.innate_nonspecific_24h_wo_LAC_IL10_IL1ra_V3_FC1.2_responder
